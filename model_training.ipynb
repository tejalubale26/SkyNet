# %% [markdown]
# # Download the dataset from Roboflow

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="WutoPQbFJA146NLmkcug")
project = rf.workspace("france-vnk03").project("face-detection-uav")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.11, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Face-Detection---UAV--7 in yolov8:: 100%|██████████| 5174/5174 [00:00<00:00, 19050.42it/s]

# %% [markdown]
# # Model Training

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8x.pt")

# %%
results = model.train(data=r"/home/adyansh/uav_autonomous_ML/face_detection/Face-Detection---UAV--7/data.yaml", 
                        epochs=120,
                        verbose=True, 
                        batch=-1,
                        device=0,
                        plots=True,
                        )
# Out:
# Ultralytics YOLOv8.2.11 🚀 Python-3.9.19 torch-2.3.0 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 11985MiB)
# ...
